# %% [markdown]
# # Imports

# %%
import warnings
warnings.filterwarnings("ignore")

import os
import re
import glob
import yaml
import subprocess

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_palette('Set3')

import IPython.display as display
from IPython.display import Video

from PIL import Image
import cv2

import torch

from ultralytics import YOLO

# %%
import ultralytics
print(ultralytics.__version__)
# Out:
# 8.1.29

# %% [markdown]
# # CFG

# %%
class CFG:
    ### inference: use any pretrained or custom model
    # WEIGHTS = 'yolov8x.pt' # yolov8n.pt, yolov8s.pt, yolov8m.pt, yolov8l.pt, yolov8x.pt
    WEIGHTS = 'models/best.pt'

    CONFIDENCE = 0.60
    CONFIDENCE_INT = int( round(CONFIDENCE * 100, 0) )

    with open('datasets/annotated_dataset/classes.txt', 'r') as file:
        CLASSES_TO_DETECT = list(range(len(file.readlines())))

    VERTICES_POLYGON = np.array([[200,720], [0,700], [500,620], [990,690], [820,720]])

    EXP_NAME = 'ppe'

    ### just some video examples
    VID_001 = 'test_videos/IMG_4504.MOV'

    ### choose filepath to make inference on (image or video)
    PATH_TO_INFER_ON = VID_001
    EXT = PATH_TO_INFER_ON.split('.')[-1] # get file extension
    FILENAME_TO_INFER_ON = PATH_TO_INFER_ON.split('/')[-1].split('.')[0] # get filename

    ### paths
    ROOT_DIR = 'test_videos'
    OUTPUT_DIR = './'

# %%
glob.glob(CFG.ROOT_DIR + '*')
# Out:
# ['test_videos']

# %% [markdown]
# ## Image utils

# %%
def get_image_properties(image):
    if isinstance(image, str):
        # If image is a file path, read the image
        img = cv2.imread(image)
        if img is None:
            raise ValueError("Could not read image file")
    elif isinstance(image, np.ndarray):
        # If image is already a NumPy array, use it directly
        img = image
    else:
        raise ValueError("Input must be a file path or a NumPy array")

    # Get image properties
    properties = {
        "width": img.shape[1],
        "height": img.shape[0],
        "channels": img.shape[2] if len(img.shape) == 3 else 1,
        "dtype": img.dtype,
    }

    return properties

# %%
def display_image(image, print_info = True, hide_axis = False):
    if isinstance(image, str):  # Check if it's a file path
        img = Image.open(image)
        plt.imshow(img)
    elif isinstance(image, np.ndarray):  # Check if it's a NumPy array
        image = image[..., ::-1]  # BGR to RGB
        img = Image.fromarray(image)
        plt.imshow(img);
    else:
        raise ValueError("Unsupported image format")

    if print_info:
        print('Type: ', type(img), '\n')
        print('Shape: ', np.array(img).shape, '\n')

    if hide_axis:
        plt.axis('off')

    plt.show()

# %% [markdown]
# ## Video utils

# %%
def get_video_properties(video_path):
    # Open the video file
    cap = cv2.VideoCapture(video_path)

    # Check if the video file is opened successfully
    if not cap.isOpened():
        raise ValueError("Could not open video file")

    # Get video properties
    properties = {
        "fps": int(cap.get(cv2.CAP_PROP_FPS)),
        "frame_count": int(cap.get(cv2.CAP_PROP_FRAME_COUNT)),
        "duration_seconds": int( cap.get(cv2.CAP_PROP_FRAME_COUNT) / cap.get(cv2.CAP_PROP_FPS) ),
        "width": int(cap.get(cv2.CAP_PROP_FRAME_WIDTH)),
        "height": int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT)),
        "codec": int(cap.get(cv2.CAP_PROP_FOURCC)),
    }

    # Release the video capture object
    cap.release()

    return properties

# %%
### testing function
video_properties = get_video_properties(CFG.VID_001)
video_properties
# Out:
# {'fps': 30,
#  'frame_count': 216,
#  'duration_seconds': 7,
#  'width': 464,
#  'height': 848,
#  'codec': 875967080}

# %%
model = YOLO(CFG.WEIGHTS)

# %%
if torch.cuda.is_available():
    model.to('cuda:0')
else:
    print("CUDA device is not available. Running on CPU.")
# Out:
# CUDA device is not available. Running on CPU.

# %%
print('Device: ', model.device)
print('Weights: ', CFG.WEIGHTS)
# Out:
# Device:  cpu
# Weights:  best.pt

# %%
# model.model
model.names
# Out:
# {0: 'Helmet',
#  1: 'Safety_Goggles',
#  2: 'Vest',
#  3: 'Hairnet',
#  4: 'Earplug',
#  5: 'No_Helmet',
#  6: 'No_Safety_Goggles',
#  7: 'No_Vest',
#  8: 'No_Hairnet',
#  9: 'No_Earplug',
#  10: 'Person'}

# %% [markdown]
# # ⚡Inference

# %%
# %%time

results = model.predict(
    source = CFG.PATH_TO_INFER_ON,
    save = True,
    classes = CFG.CLASSES_TO_DETECT,
    conf = CFG.CONFIDENCE,
    save_txt = False,
    save_conf = False,
    show = True,
    # stream = True,
)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 (no detections), 88.0ms
# video 1/1 (frame 2/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 (no detections), 71.1ms
# video 1/1 (frame 3/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 72.8ms
# video 1/1 (frame 4/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 63.1ms
# video 1/1 (frame 5/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 1 Person, 61.8ms
# video 1/1 (frame 6/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 60.7ms
# video 1/1 (frame 7/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 1 Person, 65.2ms
# video 1/1 (frame 8/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 1 Person, 66.4ms
# video 1/1 (frame 9/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 64.3ms
# video 1/1 (frame 10/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 2 Persons, 68.0ms
# video 1/1 (frame 11/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 2 Persons, 66.0ms
# video 1/1 (frame 12/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 2 Persons, 62.8ms
# video 1/1 (frame 13/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 62.9ms
# video 1/1 (frame 14/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 2 Persons, 64.7ms
# video 1/1 (frame 15/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 2 Persons, 59.7ms
# video 1/1 (frame 16/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 2 Persons, 84.7ms
# video 1/1 (frame 17/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 1 Person, 63.3ms
# video 1/1 (frame 18/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 72.7ms
# video 1/1 (frame 19/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 81.7ms
# video 1/1 (frame 20/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 1 Person, 65.7ms
# video 1/1 (frame 21/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 58.9ms
# video 1/1 (frame 22/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 54.9ms
# video 1/1 (frame 23/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 1 Person, 56.0ms
# video 1/1 (frame 24/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Earplug, 1 Person, 62.4ms
# video 1/1 (frame 25/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 62.6ms
# video 1/1 (frame 26/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 57.4ms
# video 1/1 (frame 27/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 58.3ms
# video 1/1 (frame 28/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 58.6ms
# video 1/1 (frame 29/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 58.2ms
# video 1/1 (frame 30/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 55.2ms
# video 1/1 (frame 31/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 54.9ms
# video 1/1 (frame 32/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 66.0ms
# video 1/1 (frame 33/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 2 Persons, 61.2ms
# video 1/1 (frame 34/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 2 Persons, 54.8ms
# video 1/1 (frame 35/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Earplug, 1 Person, 62
216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 62.1ms
# video 1/1 (frame 167/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 58.2ms
# video 1/1 (frame 168/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 60.3ms
# video 1/1 (frame 169/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 56.2ms
# video 1/1 (frame 170/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 62.6ms
# video 1/1 (frame 171/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 59.9ms
# video 1/1 (frame 172/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 59.2ms
# video 1/1 (frame 173/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 60.7ms
# video 1/1 (frame 174/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 64.4ms
# video 1/1 (frame 175/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 61.6ms
# video 1/1 (frame 176/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 58.6ms
# video 1/1 (frame 177/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 56.6ms
# video 1/1 (frame 178/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 62.5ms
# video 1/1 (frame 179/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 58.5ms
# video 1/1 (frame 180/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 59.4ms
# video 1/1 (frame 181/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 57.7ms
# video 1/1 (frame 182/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 62.4ms
# video 1/1 (frame 183/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 61.0ms
# video 1/1 (frame 184/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 60.5ms
# video 1/1 (frame 185/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 60.9ms
# video 1/1 (frame 186/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 70.1ms
# video 1/1 (frame 187/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 60.0ms
# video 1/1 (frame 188/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 55.4ms
# video 1/1 (frame 189/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 56.1ms
# video 1/1 (frame 190/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 62.2ms
# video 1/1 (frame 191/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 60.2ms
# video 1/1 (frame 192/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 56.7ms
# video 1/1 (frame 193/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 66.5ms
# video 1/1 (frame 194/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 60.7ms
# video 1/1 (frame 195/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 59.0ms
# video 1/1 (frame 196/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 56.1ms
# video 1/1 (frame 197/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 59.3ms
# video 1/1 (frame 198/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 62.2ms
# video 1/1 (frame 199/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 58.5ms
# video 1/1 (frame 200/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 57.5ms
# video 1/1 (frame 201/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 59.6ms
# video 1/1 (frame 202/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 63.4ms
# video 1/1 (frame 203/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 58.6ms
# video 1/1 (frame 204/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 58.9ms
# video 1/1 (frame 205/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 58.3ms
# video 1/1 (frame 206/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 64.1ms
# video 1/1 (frame 207/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 55.9ms
# video 1/1 (frame 208/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 55.2ms
# video 1/1 (frame 209/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 59.6ms
# video 1/1 (frame 210/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Person, 62.0ms
# video 1/1 (frame 211/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 Person, 57.4ms
# video 1/1 (frame 212/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 No_Vest, 1 Person, 56.6ms
# video 1/1 (frame 213/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 No_Helmet, 1 No_Vest, 1 Person, 60.2ms
# video 1/1 (frame 214/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 No_Vest, 1 Person, 63.2ms
# video 1/1 (frame 215/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 No_Vest, 1 Person, 57.0ms
# video 1/1 (frame 216/216) /Users/akbaig/Projects/Hackathon/PPE-Detection-YOLO/test_videos/IMG_4504.MOV: 640x352 1 Hairnet, 1 No_Vest, 1 Person, 62.0ms
# Speed: 1.2ms preprocess, 62.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 352)
# Results saved to runs/detect/predict2
# CPU times: user 1min, sys: 7.81 s, total: 1min 8s
# Wall time: 17.1 s

# %%
OUT_VIDEO_NAME = 'runs/detect/predict2/{}.mp4'.format(CFG.FILENAME_TO_INFER_ON)
Video(data=OUT_VIDEO_NAME, embed=True, height=int(video_properties['height'] * 0.5), width=int(video_properties['width'] * 0.5))
# Out:
# <video controls  width="232"  height="424">
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
